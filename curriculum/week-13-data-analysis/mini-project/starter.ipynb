# %% [markdown]
# # Week 13 Mini-Project — Real-World Dataset Analysis
#
# **Your name:**  _replace with your name_
#
# **Dataset:**  _replace with the dataset name and source URL_
#
# **Question I want to answer:**  _one sentence — e.g. "Which Olympic
# country has improved the most over the last 40 years?"_
#
# ---
#
# Work through the six numbered sections below in order. Replace every
# placeholder (`# TODO`, `_replace..._`) before submitting.

# %% [markdown]
# ## Imports & setup
#
# These three imports plus a small display tweak are the canonical pandas
# starting block. Add others (seaborn, requests, etc.) only as you need
# them.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 30)
FIGURES_DIR = Path("figures")
FIGURES_DIR.mkdir(exist_ok=True)

print("pandas", pd.__version__)

# %% [markdown]
# ## 1. Load
#
# Replace the path / URL below with your dataset. If your file is large,
# use `nrows=10_000` while you develop the notebook and remove it for the
# final run.

# %%
# TODO: replace with your dataset path or URL
DATA_PATH = "data/your_dataset.csv"

# df = pd.read_csv(DATA_PATH, parse_dates=["date_column"])
# df.head()

# %% [markdown]
# ## 2. Inspect
#
# Run each of these cells. Don't skip any — they form your 30-second mental
# model of the data.

# %%
# TODO: shape and dtypes
# print(df.shape)
# df.dtypes

# %%
# TODO: info() and describe()
# df.info()
# df.describe(include="all")

# %%
# TODO: missing-data audit
# missing = df.isna().sum().sort_values(ascending=False)
# missing[missing > 0]

# %% [markdown]
# ## 3. Clean
#
# Typical moves go here:
#
# - Normalize column names: `df.columns = [c.lower().strip().replace(" ", "_") for c in df.columns]`
# - Convert dtypes: `df["date"] = pd.to_datetime(df["date"])`
# - Drop or fill missing values: `df = df.dropna(subset=["price"])`
# - Build derived columns: `df["month"] = df["date"].dt.to_period("M")`
#
# Add a brief comment for each transformation so a reviewer can follow your
# reasoning.

# %%
# TODO: clean the data step by step
# df.columns = [c.lower().strip().replace(" ", "_") for c in df.columns]
# df = df.dropna(subset=["important_col"])
# df["price"] = pd.to_numeric(df["price"], errors="coerce")
# df.head()

# %% [markdown]
# ## 4. Analyze
#
# At least **two** aggregations or pivot tables. Common patterns:
#
# ```python
# df.groupby("category").agg(
#     total=("amount", "sum"),
#     avg=("amount", "mean"),
#     n=("amount", "size"),
# )
#
# df.pivot_table(index="year", columns="region", values="amount", aggfunc="sum")
# ```

# %%
# TODO: first aggregation

# %%
# TODO: second aggregation or pivot

# %% [markdown]
# ## 5. Visualize
#
# At least **three** charts. Each one must have a title and labelled axes.
# Save your favourite to `figures/main.png`.

# %%
# TODO: chart #1 — e.g. a bar chart of totals by category
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.bar(summary.index, summary["total"])
# ax.set_title("...")
# ax.set_xlabel("...")
# ax.set_ylabel("...")
# fig.tight_layout()
# fig.savefig(FIGURES_DIR / "main.png", dpi=150, bbox_inches="tight")

# %%
# TODO: chart #2 — e.g. a line chart over time

# %%
# TODO: chart #3 — your choice (scatter, histogram, box, etc.)

# %% [markdown]
# ## 6. Conclude
#
# Replace this cell with 2–3 sentences answering:
#
# - What is the single most interesting thing you found in this dataset?
# - Back it up with **one specific number** (e.g. "average X grew from
#   12.4 to 19.8 between 2010 and 2024 — a 60% increase").
# - What would you investigate next if you had another week?
#
# Also copy this summary into `findings.md` next to this notebook.

# %% [markdown]
# _Your conclusion here._
